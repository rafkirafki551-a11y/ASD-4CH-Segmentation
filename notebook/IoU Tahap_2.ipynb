# %%
import os
import json
import numpy as np
import pandas as pd
from shapely.geometry import Polygon
from shapely.validation import explain_validity

def check_and_fix_polygon(points):
    """Memeriksa dan memperbaiki polygon jika tidak valid."""
    polygon = Polygon(points)

    if not polygon.is_valid:
        print("Polygon tidak valid! Kesalahan:", explain_validity(polygon))

        # 1. Perbaiki dengan buffer(0)
        fixed_polygon = polygon.buffer(0)
        if fixed_polygon.is_valid:
            print("Polygon berhasil diperbaiki dengan buffer(0).")
            return fixed_polygon
        
        # 2. Pastikan polygon tertutup (titik awal = titik akhir)
        if points[0] != points[-1]:
            points.append(points[0])
            polygon = Polygon(points)
            if polygon.is_valid:
                print("Polygon berhasil diperbaiki dengan menutup titik.")
                return polygon

        # 3. Hapus titik duplikat
        unique_points = []
        for p in points:
            if p not in unique_points:
                unique_points.append(p)
        polygon = Polygon(unique_points)
        if polygon.is_valid:
            print("Polygon berhasil diperbaiki dengan menghapus titik duplikat.")
            return polygon

        # 4. Gunakan convex hull sebagai solusi terakhir
        fixed_polygon = polygon.convex_hull
        print("Menggunakan convex hull sebagai solusi terakhir.")
        return fixed_polygon
    
    return polygon

def compute_iou(poly1, poly2):
    """Menghitung Intersection over Union (IoU) antara dua polygon."""
    intersection = poly1.intersection(poly2).area
    union = poly1.union(poly2).area
    return intersection / union if union > 0 else 0.0

def process_json_files(gt_folder, pred_folder, output_file):
    """Membaca file JSON dari dua folder dan menyimpan IoU ke dalam file Excel."""
    results = []

    for filename in os.listdir(gt_folder):
        if filename.endswith(".json") and filename in os.listdir(pred_folder):
            gt_filepath = os.path.join(gt_folder, filename)
            pred_filepath = os.path.join(pred_folder, filename)

            with open(gt_filepath, 'r') as gt_file, open(pred_filepath, 'r') as pred_file:
                gt_data = json.load(gt_file)
                pred_data = json.load(pred_file)

                if "shapes" in gt_data and "shapes" in pred_data:
                    gt_polygons = {shape["label"].strip().lower(): shape["points"] for shape in gt_data["shapes"]}
                    pred_polygons = {shape["label"].strip().lower(): shape["points"] for shape in pred_data["shapes"]}

                    # Debugging: Periksa label yang tersedia
                    print(f"\n=== {filename} ===")
                    print("Ground Truth labels:", gt_polygons.keys())
                    print("Prediction labels:", pred_polygons.keys())

                    # Cek semua label yang ada di ground truth dan prediction
                    common_labels = set(gt_polygons.keys()).intersection(set(pred_polygons.keys()))

                    for label in common_labels:
                        gt_polygon = check_and_fix_polygon(gt_polygons[label])
                        pred_polygon = check_and_fix_polygon(pred_polygons[label])

                        if gt_polygon.is_valid and pred_polygon.is_valid:
                            iou = compute_iou(gt_polygon, pred_polygon)
                            results.append({"Image": filename, "Object": label, "IoU": iou})
                            print(f"IoU untuk {label} di {filename} = {iou:.4f}")
                        else:
                            print(f"Polygon untuk {label} tetap tidak valid setelah perbaikan, IoU tidak dihitung!")

    # Simpan hasil ke file Excel
    df = pd.DataFrame(results)
    df.to_excel(output_file, index=False)
    print(f"Hasil IoU disimpan di {output_file}")

# Contoh penggunaan
gt_folder = "D:\\DATA RAFKI\\PunyaResti\\PunyaResti\\DATASET SMARTPHONE\\4CH\\test\\images"  # Ganti dengan path folder ground truth
pred_folder = "D:\\DATA RAFKI\\PunyaResti\\PunyaResti\\DATASET SMARTPHONE\\4CH\\TEST_4CH_JSON"  # Ganti dengan path folder prediction
output_file = "D:\\DATA RAFKI\\PunyaResti\\PunyaResti\\DATASET SMARTPHONE\\4CH\\TEST_4CH.xlsx"  # File output Excel
process_json_files(gt_folder, pred_folder, output_file)
# Out:
# === ABBAS-MURTHADO_NORMAL_4CH_frame_124.json ===
# Ground Truth labels: dict_keys(['ivs', 'ias'])
# Prediction labels: dict_keys(['ivs', 'ias'])
# IoU untuk ivs di ABBAS-MURTHADO_NORMAL_4CH_frame_124.json = 0.6506
# IoU untuk ias di ABBAS-MURTHADO_NORMAL_4CH_frame_124.json = 0.5477
#
# === ABBAS-MURTHADO_NORMAL_4CH_frame_161.json ===
# Ground Truth labels: dict_keys(['ivs', 'ias'])
# Prediction labels: dict_keys(['ias', 'ivs'])
# IoU untuk ias di ABBAS-MURTHADO_NORMAL_4CH_frame_161.json = 0.6896
# IoU untuk ivs di ABBAS-MURTHADO_NORMAL_4CH_frame_161.json = 0.5425
#
# === ABBAS-MURTHADO_NORMAL_4CH_frame_17.json ===
# Ground Truth labels: dict_keys(['ivs', 'ias'])
# Prediction labels: dict_keys(['ias', 'ivs'])
# IoU untuk ias di ABBAS-MURTHADO_NORMAL_4CH_frame_17.json = 0.7248
# IoU untuk ivs di ABBAS-MURTHADO_NORMAL_4CH_frame_17.json = 0.6779
#
# === ABBAS-MURTHADO_NORMAL_4CH_frame_186.json ===
# Ground Truth labels: dict_keys(['ivs', 'ias'])
# Prediction labels: dict_keys(['ias', 'ivs'])
# IoU untuk ias di ABBAS-MURTHADO_NORMAL_4CH_frame_186.json = 0.7161
# IoU untuk ivs di ABBAS-MURTHADO_NORMAL_4CH_frame_186.json = 0.7748
#
# === ABBAS-MURTHADO_NORMAL_4CH_frame_218.json ===
# Ground Truth labels: dict_keys(['ivs', 'ias'])
# Prediction labels: dict_keys(['ias', 'ivs'])
# IoU untuk ias di ABBAS-MURTHADO_NORMAL_4CH_frame_218.json = 0.7848
# IoU untuk ivs di ABBAS-MURTHADO_NORMAL_4CH_frame_218.json = 0.5541
#
# === ABBAS-MURTHADO_NORMAL_4CH_frame_268.json ===
# Ground Truth labels: dict_keys(['ivs', 'ias'])
# Prediction labels: dict_keys(['ias', 'ivs'])
# IoU untuk ias di ABBAS-MURTHADO_NORMAL_4CH_frame_268.json = 0.6197
# IoU untuk ivs di ABBAS-MURTHADO_NORMAL_4CH_frame_268.json = 0.4437
#
# === ABBAS-MURTHADO_NORMAL_4CH_frame_276.json ===
# Ground Truth labels: dict_keys(['ivs', 'ias'])
# Prediction labels: dict_keys(['ias', 'ivs'])
# IoU untuk ias di ABBAS-MURTHADO_NORMAL_4CH_frame_276.json = 0.6787
# IoU untuk ivs di ABBAS-MURTHADO_NORMAL_4CH_frame_276.json = 0.6252
#
# === ABBAS-MURTHADO_NORMAL_4CH_frame_289.json ===
# Ground Truth labels: dict_keys(['ivs', 'ias'])
# Prediction labels: dict_keys(['ias', 'ivs'])
# IoU untuk ias di ABBAS-MURTHADO_NORMAL_4CH_frame_289.json = 0.7722
# Polygon tidak valid! Kesalahan: Self-intersection[1241.68401877811 727.658687623554]
# Polygon berhasil diperbaiki dengan buffer(0).
# IoU untuk ivs di ABBAS-MURTHADO_NORMAL_4CH_frame_289.json = 0.6313
#
# === ABBAS-MURTHADO_NORMAL_4CH_frame_4.json ===
# Ground Truth labels: dict_keys(['ivs', 'ias'])
# Prediction labels: dict_keys(['ias', 'ivs'])
# IoU untuk ias di ABBAS-MURTHADO_NORMAL_4CH_frame_4.json = 0.7371
# IoU untuk ivs di ABBAS-MURTHADO_NORMAL_4CH_frame_4.json = 0.7023
#
# === ABBAS-MURTHADO_NORMAL_4CH_frame_77.json ===
# Ground Truth labels: dict_keys(['ivs', 'ias'])
# Prediction labels: dict_keys(['ias', 'ivs'])
# IoU untuk ias di ABBAS-MURTHADO_NORMAL_4CH_frame_77.json = 0.5845
# IoU untuk ivs di ABBAS-MURTHADO_NORMAL_4CH_frame_77.json = 0.6185
#
# === ADIFA_4CH_frame_108.json ===
# Ground Truth labels: dict_keys(['h', 'ias', 'ivs'])
# Prediction labels: dict_keys(['ivs', 'ias', 'h'])
# IoU untuk ivs di ADIFA_4CH_frame_108.json = 0.7971
# IoU untuk h di ADIFA_4CH_frame_108.json = 0.3111
# IoU untuk ias di ADIFA_4CH_frame_108.json = 0.3217
#
# === ADIFA_4CH_frame_178.json ===
# Ground Truth labels: dict_keys(['h', 'ias', 'ivs'])
# Prediction labels: dict_keys(['ivs', 'ias'])
# IoU untuk ivs di ADIFA_4CH_frame_178.json = 0.7674
# IoU untuk ias di ADIFA_4CH_frame_178.json = 0.4903
#
# === ADIFA_4CH_frame_233.json ===
# Ground Truth labels: dict_keys(['h', 'ias', 'ivs'])
# Prediction labels: dict_keys(['ivs', 'ias'])
# IoU untuk ivs di ADIFA_4CH_frame_233.json = 0.7518
# IoU untuk ias di ADIFA_4CH_frame_233.json = 0.6315
#
# === ADIFA_4CH_frame_249.json ===
# Ground Truth labels: dict_keys(['ivs', 'h', 'ias'])
# Prediction labels: dict_keys(['ivs', 'ias'])
# IoU untuk ivs di ADIFA_4CH_frame_249.json = 0.6906
# IoU untuk ias di ADIFA_4CH_frame_249.json = 0.0000
#
# === ADIFA_4CH_frame_25.json ===
# Ground Truth labels: dict_keys(['h', 'ias', 'ivs'])
# Prediction labels: dict_keys(['ivs', 'ias'])
# IoU untuk ivs di ADIFA_4CH_frame_25.json = 0.7917
# IoU untuk ias di ADIFA_4CH_frame_25.json = 0.5203
#
# === ADIFA_4CH_frame_262.json ===
# Ground Truth labels: dict_keys(['ias', 'h', 'ivs'])
# Prediction labels: dict_keys(['ias', 'ivs'])
# IoU untuk ias di ADIFA_4CH_frame_262.json = 0.2546
# IoU untuk ivs di ADIFA_4CH_frame_262.json = 0.4408
#
# === ADIFA_4CH_frame_58.json ===
# Ground Truth labels: dict_keys(['h', 'ias', 'ivs'])
# Prediction labels: dict_keys(['ivs', 'ias'])
# IoU untuk ivs di ADIFA_4CH_frame_58.json = 0.5993
# IoU untuk ias di ADIFA_4CH_frame_58.json = 0.6829
#
# === ADIFA_4CH_frame_61.json ===
# Ground Truth labels: dict_keys(['ias', 'h', 'ivs'])
# Prediction labels: dict_keys(['ias', 'ivs'])
# IoU untuk ias di ADIFA_4CH_frame_61.json = 0.1125
# IoU untuk ivs di ADIFA_4CH_frame_61.json = 0.6511
#
# === ADIFA_4CH_frame_7.json ===
# Ground Truth labels: dict_keys(['ias', 'h', 'ivs'])
# Prediction labels: dict_keys(['ias', 'ivs'])
# IoU untuk ias di ADIFA_4CH_frame_7.json = 0.1936
# IoU untuk ivs di ADIFA_4CH_frame_7.json = 0.4497
#
# === ADIFA_4CH_frame_96.json ===
# Ground Truth labels: dict_keys(['ivs', 'ias', 'h'])
# Prediction labels: dict_keys(['ivs', 'ias', 'h'])
# IoU untuk ivs di ADIFA_4CH_frame_96.json = 0.7173
# IoU untuk h di ADIFA_4CH_frame_96.json = 0.6172
# IoU untuk ias di ADIFA_4CH_frame_96.json = 0.5971
#
# === AL HAFIZH_4CH_frame_0000.json ===
# Ground Truth labels: dict_keys(['ias', 'ivs', 'h'])
# Prediction labels: dict_keys(['ias', 'ivs'])
# IoU untuk ias di AL HAFIZH_4CH_frame_0000.json = 0.6756
# IoU untuk ivs di AL HAFIZH_4CH_frame_0000.json = 0.6787
#
# === AL HAFIZH_4CH_frame_0001.json ===
# Ground Truth labels: dict_keys(['ias', 'h', 'ivs'])
# Prediction labels: dict_keys(['ias', 'h'])
# IoU untuk h di AL HAFIZH_4CH_frame_0001.json = 0.0000
# IoU untuk ias di AL HAFIZH_4CH_frame_0001.json = 0.4312
#
# === AL HAFIZH_4CH_frame_0002.json ===
# Ground Truth labels: dict_keys(['ias', 'h', 'ivs'])
# Prediction labels: dict_keys(['ias', 'ivs'])
# IoU untuk ias di AL HAFIZH_4CH_frame_0002.json = 0.5241
# IoU untuk ivs di AL HAFIZH_4CH_frame_0002.json = 0.2109
#
# === AL HAFIZH_4CH_frame_0007.json ===
# Ground Truth labels: dict_keys(['ias', 'h', 'ivs'])
# Prediction labels: dict_keys(['ivs'])
# IoU untuk ivs di AL HAFIZH_4CH_frame_0007.json = 0.4966
#
# === AL HAFIZH_4CH_frame_0008.json ===
# Ground Truth labels: dict_keys(['ias', 'h', 'ivs'])
# Prediction labels: dict_keys(['ias'])
# IoU untuk ias di AL HAFIZH_4CH_frame_0008.json = 0.7191
#
# === AL HAFIZH_4CH_frame_0009.json ===
# Ground Truth labels: dict_keys(['ias', 'h', 'ivs'])
# Prediction labels: dict_keys(['ias'])
# IoU untuk ias di AL HAFIZH_4CH_frame_0009.json = 0.6619
#
# === AL HAFIZH_4CH_frame_0010.json ===
# Ground Truth labels: dict_keys(['ias', 'h', 'ivs'])
# Prediction labels: dict_keys(['ias', 'h', 'ivs'])
# IoU untuk ias di AL HAFIZH_4CH_frame_0010.json = 0.7181
# IoU untuk h di AL HAFIZH_4CH_frame_0010.json = 0.0000
# IoU untuk ivs di AL HAFIZH_4CH_frame_0010.json = 0.3482
#
# === AL HAFIZH_4CH_frame_0011.json ===
# Ground Truth labels: dict_keys(['ias', 'h', 'ivs'])
# Prediction labels: dict_keys(['h', 'ias', 'ivs'])
# IoU untuk ias di AL HAFIZH_4CH_frame_0011.json = 0.6133
# IoU untuk h di AL HAFIZH_4CH_frame_0011.json = 0.0000
# IoU untuk ivs di AL HAFIZH_4CH_frame_0011.json = 0.2606
#
# === AL HAFIZH_4CH_frame_0012.json ===
# Ground Truth labels: dict_keys(['ias', 'h', 'ivs'])
# Prediction labels: dict_keys(['ias', 'h'])
# IoU untuk h di AL HAFIZH_4CH_frame_0012.json = 0.0000
# IoU untuk ias di AL HAFIZH_4CH_frame_0012.json = 0.6031
#
# === AL HAFIZH_4CH_frame_0013.json ===
# Ground Truth labels: dict_keys(['ias', 'h', 'ivs'])
# Prediction labels: dict_keys(['h'])
# IoU untuk h di AL HAFIZH_4CH_frame_0013.json = 0.0000
#
# === CLARETA_4CH_frame_105.json ===
# Ground Truth labels: dict_keys(['ias', 'ivs'])
# Prediction labels: dict_keys(['ivs', 'ias'])
# IoU untuk ivs di CLARETA_4CH_frame_105.json = 0.6458
# IoU untuk ias di CLARETA_4CH_frame_105.json = 0.6722
#
# === CLARETA_4CH_frame_115.json ===
# Ground Truth labels: dict_keys(['ias', 'ivs'])
# Prediction labels: dict_keys(['ivs', 'ias'])
# IoU untuk ivs di CLARETA_4CH_frame_115.json = 0.5698
# IoU untuk ias di CLARETA_4CH_frame_115.json = 0.7654
#
# === CLARETA_4CH_frame_138.json ===
# Ground Truth labels: dict_keys(['ias', 'ivs'])
# Prediction labels: dict_keys(['ias', 'ivs'])
# IoU untuk ias di CLARETA_4CH_frame_138.json = 0.7026
# IoU untuk ivs di CLARETA_4CH_frame_138.json = 0.6573
#
# === CLARETA_4CH_frame_212.json ===
# Ground Truth labels: dict_keys(['ias', 'ivs'])
# Prediction labels: dict_keys(['ias', 'ivs'])
# IoU untuk ias di CLARETA_4CH_frame_212.json = 0.6614
# IoU untuk ivs di CLARETA_4CH_frame_212.json = 0.5705
#
# === CLARETA_4CH_frame_213.json ===
# Ground Truth labels: dict_keys(['ias', 'ivs'])
# Prediction labels: dict_keys(['ivs', 'ias'])
# IoU untuk ivs di CLARETA_4CH_frame_213.json = 0.6538
# IoU untuk ias di CLARETA_4CH_frame_213.json = 0.6865
#
# === CLARETA_4CH_frame_215.json ===
# Ground Truth labels: dict_keys(['ias', 'ivs'])
# Prediction labels: dict_keys(['ias', 'ivs'])
# IoU untuk ias di CLARETA_4CH_frame_215.json = 0.6526
# IoU untuk ivs di CLARETA_4CH_frame_215.json = 0.6518
#
# === CLARETA_4CH_frame_228.json ===
# Ground Truth labels: dict_keys(['ias', 'ivs'])
# Prediction labels: dict_keys(['ivs', 'ias'])
# IoU untuk ivs di CLARETA_4CH_frame_228.json = 0.4388
# IoU untuk ias di CLARETA_4CH_frame_228.json = 0.5795
#
# === CLARETA_4CH_frame_233.json ===
# Ground Truth labels: dict_keys(['ias', 'ivs'])
# Prediction labels: dict_keys(['ias', 'ivs'])
# IoU untuk ias di CLARETA_4CH_frame_233.json = 0.6182
# IoU untuk ivs di CLARETA_4CH_frame_233.json = 0.6014
#
# === CLARETA_4CH_frame_287.json ===
# Ground Truth labels: dict_keys(['ias', 'ivs'])
# Prediction labels: dict_keys(['ias', 'ivs'])
# IoU untuk ias di CLARETA_4CH_frame_287.json = 0.6625
# IoU untuk ivs di CLARETA_4CH_frame_287.json = 0.3917
#
# === CLARETA_4CH_frame_49.json ===
# Ground Truth labels: dict_keys(['ias', 'ivs'])
# Prediction labels: dict_keys(['ias', 'ivs'])
# IoU untuk ias di CLARETA_4CH_frame_49.json = 0.6694
# IoU untuk ivs di CLARETA_4CH_frame_49.json = 0.4567
#
# === DEVIN_4CH_frame_129.json ===
# Ground Truth labels: dict_keys(['ias', 'ivs'])
# Prediction labels: dict_keys(['ias', 'ivs'])
# IoU untuk ias di DEVIN_4CH_frame_129.json = 0.4494
# IoU untuk ivs di DEVIN_4CH_frame_129.json = 0.4182
#
# === DEVIN_4CH_frame_192.json ===
# Ground Truth labels: dict_keys(['ias', 'ivs'])
# Prediction labels: dict_keys(['ias', 'ivs'])
# IoU untuk ias di DEVIN_4CH_frame_192.json = 0.7438
# IoU untuk ivs di DEVIN_4CH_frame_192.json = 0.5341
#
# === DEVIN_4CH_frame_199.json ===
# Ground Truth labels: dict_keys(['ias', 'ivs'])
# Prediction labels: dict_keys(['ias', 'ivs'])
# IoU untuk ias di DEVIN_4CH_frame_199.json = 0.6687
# IoU untuk ivs di DEVIN_4CH_frame_199.json = 0.5486
#
# === DEVIN_4CH_frame_215.json ===
# Ground Truth labels: dict_keys(['ias', 'ivs'])
# Prediction labels: dict_keys(['ias', 'ivs'])
# IoU untuk ias di DEVIN_4CH_frame_215.json = 0.6194
# IoU untuk ivs di DEVIN_4CH_frame_215.json = 0.4046
#
# === DEVIN_4CH_frame_265.json ===
# Ground Truth labels: dict_keys(['ias', 'ivs'])
# Prediction labels: dict_keys(['ias', 'ivs'])
# IoU untuk ias di DEVIN_4CH_frame_265.json = 0.7638
# IoU untuk ivs di DEVIN_4CH_frame_265.json = 0.4716
#
# === DEVIN_4CH_frame_281.json ===
# Ground Truth labels: dict_keys(['ias', 'ivs'])
# Prediction labels: dict_keys(['ias', 'ivs'])
# IoU untuk ias di DEVIN_4CH_frame_281.json = 0.6838
# IoU untuk ivs di DEVIN_4CH_frame_281.json = 0.4535
#
# === DEVIN_4CH_frame_67.json ===
# Ground Truth labels: dict_keys(['ias', 'ivs'])
# Prediction labels: dict_keys(['ias', 'ivs'])
# IoU untuk ias di DEVIN_4CH_frame_67.json = 0.7321
# IoU untuk ivs di DEVIN_4CH_frame_67.json = 0.4657
#
# === DEVIN_4CH_frame_71.json ===
# Ground Truth labels: dict_keys(['ias', 'ivs'])
# Prediction labels: dict_keys(['ias', 'ivs'])
# IoU untuk ias di DEVIN_4CH_frame_71.json = 0.7436
# IoU untuk ivs di DEVIN_4CH_frame_71.json = 0.5452
#
# === DEVIN_4CH_frame_86.json ===
# Ground Truth labels: dict_keys(['ias', 'ivs'])
# Prediction labels: dict_keys(['ias', 'ivs'])
# IoU untuk ias di DEVIN_4CH_frame_86.json = 0.7713
# IoU untuk ivs di DEVIN_4CH_frame_86.json = 0.5081
#
# === DEVIN_4CH_frame_89.json ===
# Ground Truth labels: dict_keys(['ias', 'ivs'])
# Prediction labels: dict_keys(['ias', 'ivs'])
# IoU untuk ias di DEVIN_4CH_frame_89.json = 0.6018
# IoU untuk ivs di DEVIN_4CH_frame_89.json = 0.5431
#
# === DEWI_KHAIRUNISA_4CH_frame_137.json ===
# Ground Truth labels: dict_keys(['h', 'ias', 'ivs'])
# Prediction labels: dict_keys(['ivs', 'h', 'ias'])
# IoU untuk ivs di DEWI_KHAIRUNISA_4CH_frame_137.json = 0.6061
# IoU untuk h di DEWI_KHAIRUNISA_4CH_frame_137.json = 0.0245
# IoU untuk ias di DEWI_KHAIRUNISA_4CH_frame_137.json = 0.5102
#
# === DEWI_KHAIRUNISA_4CH_frame_183.json ===
# Ground Truth labels: dict_keys(['h', 'ias', 'ivs'])
# Prediction labels: dict_keys(['ivs', 'ias', 'h'])
# IoU untuk ivs di DEWI_KHAIRUNISA_4CH_frame_183.json = 0.6888
# IoU untuk h di DEWI_KHAIRUNISA_4CH_frame_183.json = 0.0385
# IoU untuk ias di DEWI_KHAIRUNISA_4CH_frame_183.json = 0.4482
#
# === DEWI_KHAIRUNISA_4CH_frame_259.json ===
# Ground Truth labels: dict_keys(['h', 'ias', 'ivs'])
# Prediction labels: dict_keys(['ivs', 'ias', 'h'])
# IoU untuk ivs di DEWI_KHAIRUNISA_4CH_frame_259.json = 0.7101
# IoU untuk h di DEWI_KHAIRUNISA_4CH_frame_259.json = 0.6511
# IoU untuk ias di DEWI_KHAIRUNISA_4CH_frame_259.json = 0.6028
#
# === DEWI_KHAIRUNISA_4CH_frame_281.json ===
# Ground Truth labels: dict_keys(['h', 'ias', 'ivs'])
# Prediction labels: dict_keys(['ivs', 'ias'])
# IoU untuk ivs di DEWI_KHAIRUNISA_4CH_frame_281.json = 0.6988
# IoU untuk ias di DEWI_KHAIRUNISA_4CH_frame_281.json = 0.5363
#
# === DEWI_KHAIRUNISA_4CH_frame_292.json ===
# Ground Truth labels: dict_keys(['h', 'ias', 'ivs'])
# Prediction labels: dict_keys(['ias', 'ivs', 'h'])
# IoU untuk ias di DEWI_KHAIRUNISA_4CH_frame_292.json = 0.6318
# IoU untuk h di DEWI_KHAIRUNISA_4CH_frame_292.json = 0.4508
# IoU untuk ivs di DEWI_KHAIRUNISA_4CH_frame_292.json = 0.6090
#
# === DEWI_KHAIRUNISA_4CH_frame_298.json ===
# Ground Truth labels: dict_keys(['h', 'ias', 'ivs'])
# Prediction labels: dict_keys(['ivs', 'ias', 'h'])
# IoU untuk ivs di DEWI_KHAIRUNISA_4CH_frame_298.json = 0.5412
# IoU untuk h di DEWI_KHAIRUNISA_4CH_frame_298.json = 0.3669
# IoU untuk ias di DEWI_KHAIRUNISA_4CH_frame_298.json = 0.4586
#
# === DEWI_KHAIRUNISA_4CH_frame_70.json ===
# Ground Truth labels: dict_keys(['h', 'ias', 'ivs'])
# Prediction labels: dict_keys(['ivs', 'ias', 'h'])
# IoU untuk ivs di DEWI_KHAIRUNISA_4CH_frame_70.json = 0.7952
# IoU untuk h di DEWI_KHAIRUNISA_4CH_frame_70.json = 0.4372
# IoU untuk ias di DEWI_KHAIRUNISA_4CH_frame_70.json = 0.5966
#
# === DEWI_KHAIRUNISA_4CH_frame_76.json ===
# Ground Truth labels: dict_keys(['h', 'ias', 'ivs'])
# Prediction labels: dict_keys(['ivs', 'ias'])
# IoU untuk ivs di DEWI_KHAIRUNISA_4CH_frame_76.json = 0.6508
# IoU untuk ias di DEWI_KHAIRUNISA_4CH_frame_76.json = 0.5036
#
# === DEWI_KHAIRUNISA_4CH_frame_82.json ===
# Ground Truth labels: dict_keys(['ivs', 'h', 'ias'])
# Prediction labels: dict_keys(['ivs', 'ias'])
# IoU untuk ivs di DEWI_KHAIRUNISA_4CH_frame_82.json = 0.7975
# IoU untuk ias di DEWI_KHAIRUNISA_4CH_frame_82.json = 0.6694
#
# === DEWI_KHAIRUNISA_4CH_frame_95.json ===
# Ground Truth labels: dict_keys(['h', 'ias', 'ivs'])
# Prediction labels: dict_keys(['ivs', 'h', 'ias'])
# IoU untuk ivs di DEWI_KHAIRUNISA_4CH_frame_95.json = 0.5813
# IoU untuk h di DEWI_KHAIRUNISA_4CH_frame_95.json = 0.3270
# IoU untuk ias di DEWI_KHAIRUNISA_4CH_frame_95.json = 0.5405
#
# === HAFIZ_4CH_frame0020.json ===
# Ground Truth labels: dict_keys(['ias', 'ivs'])
# Prediction labels: dict_keys(['ias', 'ivs'])
# IoU untuk ias di HAFIZ_4CH_frame0020.json = 0.5681
# IoU untuk ivs di HAFIZ_4CH_frame0020.json = 0.5604
#
# === HAFIZ_4CH_frame0021.json ===
# Ground Truth labels: dict_keys(['ias', 'ivs'])
# Prediction labels: dict_keys(['ias', 'ivs'])
# IoU untuk ias di HAFIZ_4CH_frame0021.json = 0.5989
# IoU untuk ivs di HAFIZ_4CH_frame0021.json = 0.5928
#
# === HAFIZ_4CH_frame_140.json ===
# Ground Truth labels: dict_keys(['ias', 'ivs'])
# Prediction labels: dict_keys(['ias', 'ivs'])
# IoU untuk ias di HAFIZ_4CH_frame_140.json = 0.6237
# IoU untuk ivs di HAFIZ_4CH_frame_140.json = 0.4473
#
# === HAFIZ_4CH_frame_142.json ===
# Ground Truth labels: dict_keys(['ias', 'ivs'])
# Prediction labels: dict_keys(['ias', 'ivs'])
# IoU untuk ias di HAFIZ_4CH_frame_142.json = 0.5797
# IoU untuk ivs di HAFIZ_4CH_frame_142.json = 0.5922
#
# === HAFIZ_4CH_frame_225.json ===
# Ground Truth labels: dict_keys(['ias', 'ivs'])
# Prediction labels: dict_keys(['ias', 'ivs'])
# IoU untuk ias di HAFIZ_4CH_frame_225.json = 0.6451
# IoU untuk ivs di HAFIZ_4CH_frame_225.json = 0.5243
#
# === HAFIZ_4CH_frame_254.json ===
# Ground Truth labels: dict_keys(['ias', 'ivs'])
# Prediction labels: dict_keys(['ias', 'ivs'])
# IoU untuk ias di HAFIZ_4CH_frame_254.json = 0.6823
# IoU untuk ivs di HAFIZ_4CH_frame_254.json = 0.5162
#
# === HAFIZ_4CH_frame_255.json ===
# Ground Truth labels: dict_keys(['ias', 'ivs'])
# Prediction labels: dict_keys(['ias', 'ivs'])
# IoU untuk ias di HAFIZ_4CH_frame_255.json = 0.6594
# IoU untuk ivs di HAFIZ_4CH_frame_255.json = 0.4450
#
# === HAFIZ_4CH_frame_35.json ===
# Ground Truth labels: dict_keys(['ias', 'ivs'])
# Prediction labels: dict_keys(['ias', 'ivs'])
# IoU untuk ias di HAFIZ_4CH_frame_35.json = 0.5199
# IoU untuk ivs di HAFIZ_4CH_frame_35.json = 0.3878
#
# === HAFIZ_4CH_frame_52.json ===
# Ground Truth labels: dict_keys(['ias', 'ivs'])
# Prediction labels: dict_keys(['ias', 'ivs'])
# IoU untuk ias di HAFIZ_4CH_frame_52.json = 0.5200
# IoU untuk ivs di HAFIZ_4CH_frame_52.json = 0.5709
#
# === HAFIZ_4CH_frame_80.json ===
# Ground Truth labels: dict_keys(['ias', 'ivs'])
# Prediction labels: dict_keys(['ias', 'ivs'])
# IoU untuk ias di HAFIZ_4CH_frame_80.json = 0.6089
# IoU untuk ivs di HAFIZ_4CH_frame_80.json = 0.6191
#
# === KENZO_ATALAH_4CH_frame_103.json ===
# Ground Truth labels: dict_keys(['h', 'ias', 'ivs'])
# Prediction labels: dict_keys(['ias', 'ivs', 'h'])
# IoU untuk ias di KENZO_ATALAH_4CH_frame_103.json = 0.5533
# IoU untuk h di KENZO_ATALAH_4CH_frame_103.json = 0.4905
# IoU untuk ivs di KENZO_ATALAH_4CH_frame_103.json = 0.6462
#
# === KENZO_ATALAH_4CH_frame_135.json ===
# Ground Truth labels: dict_keys(['h', 'ias', 'ivs'])
# Prediction labels: dict_keys(['ias', 'ivs', 'h'])
# IoU untuk ias di KENZO_ATALAH_4CH_frame_135.json = 0.5730
# IoU untuk h di KENZO_ATALAH_4CH_frame_135.json = 0.3946
# IoU untuk ivs di KENZO_ATALAH_4CH_frame_135.json = 0.6500
#
# === KENZO_ATALAH_4CH_frame_2.json ===
# Ground Truth labels: dict_keys(['h', 'ias', 'ivs'])
# Prediction labels: dict_keys(['h', 'ias', 'ivs'])
# IoU untuk ias di KENZO_ATALAH_4CH_frame_2.json = 0.5444
# IoU untuk h di KENZO_ATALAH_4CH_frame_2.json = 0.5009
# IoU untuk ivs di KENZO_ATALAH_4CH_frame_2.json = 0.6929
#
# === KENZO_ATALAH_4CH_frame_21.json ===
# Ground Truth labels: dict_keys(['h', 'ias', 'ivs'])
# Prediction labels: dict_keys(['ias', 'h', 'ivs'])
# IoU untuk ias di KENZO_ATALAH_4CH_frame_21.json = 0.6347
# IoU untuk h di KENZO_ATALAH_4CH_frame_21.json = 0.4963
# IoU untuk ivs di KENZO_ATALAH_4CH_frame_21.json = 0.6363
#
# === KENZO_ATALAH_4CH_frame_31.json ===
# Ground Truth labels: dict_keys(['h', 'ias', 'ivs'])
# Prediction labels: dict_keys(['h', 'ivs', 'ias'])
# IoU untuk ivs di KENZO_ATALAH_4CH_frame_31.json = 0.7400
# IoU untuk h di KENZO_ATALAH_4CH_frame_31.json = 0.0914
# IoU untuk ias di KENZO_ATALAH_4CH_frame_31.json = 0.6348
#
# === KENZO_ATALAH_4CH_frame_43.json ===
# Ground Truth labels: dict_keys(['h', 'ias', 'ivs'])
# Prediction labels: dict_keys(['ivs', 'h', 'ias'])
# IoU untuk ivs di KENZO_ATALAH_4CH_frame_43.json = 0.5889
# IoU untuk h di KENZO_ATALAH_4CH_frame_43.json = 0.0544
# IoU untuk ias di KENZO_ATALAH_4CH_frame_43.json = 0.0181
#
# === KENZO_ATALAH_4CH_frame_5.json ===
# Ground Truth labels: dict_keys(['h', 'ias', 'ivs'])
# Prediction labels: dict_keys(['ivs', 'h', 'ias'])
# IoU untuk ivs di KENZO_ATALAH_4CH_frame_5.json = 0.6397
# IoU untuk h di KENZO_ATALAH_4CH_frame_5.json = 0.5271
# IoU untuk ias di KENZO_ATALAH_4CH_frame_5.json = 0.5733
#
# === KENZO_ATALAH_4CH_frame_57.json ===
# Ground Truth labels: dict_keys(['ias', 'h', 'ivs'])
# Prediction labels: dict_keys(['ias', 'h', 'ivs'])
# IoU untuk ias di KENZO_ATALAH_4CH_frame_57.json = 0.6113
# IoU untuk h di KENZO_ATALAH_4CH_frame_57.json = 0.6456
# IoU untuk ivs di KENZO_ATALAH_4CH_frame_57.json = 0.6073
#
# === KENZO_ATALAH_4CH_frame_74.json ===
# Ground Truth labels: dict_keys(['h', 'ias', 'ivs'])
# Prediction labels: dict_keys(['h', 'ivs', 'ias'])
# IoU untuk ivs di KENZO_ATALAH_4CH_frame_74.json = 0.7417
# IoU untuk h di KENZO_ATALAH_4CH_frame_74.json = 0.3581
# IoU untuk ias di KENZO_ATALAH_4CH_frame_74.json = 0.5320
#
# === KENZO_ATALAH_4CH_frame_91.json ===
# Ground Truth labels: dict_keys(['h', 'ias', 'ivs'])
# Prediction labels: dict_keys(['h', 'ivs', 'ias'])
# IoU untuk ivs di KENZO_ATALAH_4CH_frame_91.json = 0.7309
# IoU untuk h di KENZO_ATALAH_4CH_frame_91.json = 0.4762
# IoU untuk ias di KENZO_ATALAH_4CH_frame_91.json = 0.5497
# Hasil IoU disimpan di D:\DATA RAFKI\PunyaResti\PunyaResti\DATASET SMARTPHONE\4CH\TEST_4CH.xlsx

# %%
pip install shapely
pip install openpyxl
# Out:
# Collecting shapely
#   Downloading shapely-2.1.1-cp311-cp311-win_amd64.whl.metadata (7.0 kB)
# Requirement already satisfied: numpy>=1.21 in c:\users\isysrg.com\anaconda3\envs\yolo11\lib\site-packages (from shapely) (2.1.2)
# Downloading shapely-2.1.1-cp311-cp311-win_amd64.whl (1.7 MB)
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    ------------------ --------------------- 0.8/1.7 MB 6.7 MB/s eta 0:00:01
#    ---------------------------------------- 1.7/1.7 MB 7.1 MB/s eta 0:00:00
# Installing collected packages: shapely
# Successfully installed shapely-2.1.1
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install openpyxl
# Out:
# Collecting openpyxl
#   Using cached openpyxl-3.1.5-py2.py3-none-any.whl.metadata (2.5 kB)
# Collecting et-xmlfile (from openpyxl)
#   Using cached et_xmlfile-2.0.0-py3-none-any.whl.metadata (2.7 kB)
# Using cached openpyxl-3.1.5-py2.py3-none-any.whl (250 kB)
# Using cached et_xmlfile-2.0.0-py3-none-any.whl (18 kB)
# Installing collected packages: et-xmlfile, openpyxl
# Successfully installed et-xmlfile-2.0.0 openpyxl-3.1.5
# Note: you may need to restart the kernel to use updated packages.
